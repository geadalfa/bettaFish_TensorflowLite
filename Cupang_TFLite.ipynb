# %% [markdown]
# # **Import & Install Library**

# %%
#Import library preprocessing
from google.colab import files
import random as rd
import zipfile, os # Library untuk mendownload zipfile
from tqdm import tqdm # Sebagai pemanis visual saat mengimport gambar ke dalam array list
import numpy as np  # Library untuk mengubah gambar menjadi array
import tensorflow as tf # Library Tensorflow
from tensorflow.keras.optimizers import RMSprop # Mengimport optimizer untuk model
from tensorflow.keras.preprocessing.image import ImageDataGenerator # Library untuk Augmentasi gambar
from keras import regularizers # Library untuk mencegah overfitting pada model
from keras.callbacks import LearningRateScheduler, ModelCheckpoint # Mengimport learningrate dan model checkpoint
from sklearn.preprocessing import LabelEncoder # Untuk mengubah index menjadi string label
from keras.preprocessing import image
from keras.utils import to_categorical # Untuk melabeli gambar
import cv2 # Mengimport gambar

#Import library visualisasi
import matplotlib.image as mpimg  # Library untuk visualisai gambar dengan plot
import matplotlib.pyplot as plt # Library untuk visualisai plot
# %matplotlib inline
import seaborn as sns # Library untuk visualisai plot lebih bagus

from sklearn.metrics import confusion_matrix # Untuk evaluasi model
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Install library split_folders
# !pip install split_folders
import splitfolders
# Out:
# Collecting split_folders
#   Downloading https://files.pythonhosted.org/packages/d1/4b/7b282b0f9319189d71e803220748929b37d019b67b1782d14c59cb1bd940/split_folders-0.4.2-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.2

# %% [markdown]
# # **Import Dataset**

# %% [markdown]
# Mendownload Dataset Ikan Cupang yang diambil dari Google Images dan telah dimasukkan ke dalam Dropbox

# %%
# Mendownload dataset cupang menggunakan wget

# !wget --no-check-certificate \
  https://dl.dropbox.com/s/24shsjf988eizki/dataset_cupang.zip?dl=2 \
  -O /tmp/dataset-cupang.zip
# Out:
# --2020-09-06 05:07:38--  https://dl.dropbox.com/s/24shsjf988eizki/dataset_cupang.zip?dl=2
# Resolving dl.dropbox.com (dl.dropbox.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to dl.dropbox.com (dl.dropbox.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/s/24shsjf988eizki/dataset_cupang.zip?dl=2 [following]
# --2020-09-06 05:07:38--  https://dl.dropboxusercontent.com/s/24shsjf988eizki/dataset_cupang.zip?dl=2
# Resolving dl.dropboxusercontent.com (dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to dl.dropboxusercontent.com (dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 898296048 (857M) [application/zip]
# Saving to: ‘/tmp/dataset-cupang.zip’
#
# /tmp/dataset-cupang 100%[===================>] 856.68M  25.5MB/s    in 35s
#
# 2020-09-06 05:08:14 (24.7 MB/s) - ‘/tmp/dataset-cupang.zip’ saved [898296048/898296048]

# %%
# Mengekstrak folder zip yang telah terdownload
local_zip = '/tmp/dataset-cupang.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
 
base_dir = '/tmp/dataset-cupang'

# %% [markdown]
# Folder yang telah terekstrak akan terlihat seperti ini:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Data Preprocessing**

# %%
# Memakai library split_folders untuk membagi data train dan validasi
import splitfolders

# Membagi data train dan validasi dengan perbandingan 80% : 20%
splitfolders.ratio('/tmp/dataset-cupang', output="dataset", seed=43, ratio=(.8, .2))
# Out:
# Copying files: 13134 files [00:09, 1364.36 files/s]

# %%
# Menentukan path data train dan validasi
path = "/content/dataset/"
train_dir = path + "train" 
validation_dir = path + "val"

# %%
print(train_dir)
print(validation_dir)
# Out:
# /content/dataset/train
# /content/dataset/val

# %% [markdown]
# Splitting akan terlihat seperti gambar di berikut ini:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Memasukkan Data Validasi ke dalam Array List

# %%
print(os.listdir('/tmp/dataset-cupang'))
# Out:
# ['Cupang Crowntail Super Red', 'Cupang Halfmoon Nemo', 'Cupang Plakat Blue Rim', 'Cupang Halfmoon Red Cooper', 'Cupang Halfmoon Blue', 'Cupang Halfmoon Multicolor', 'Cupang Halfmoon Red', 'Cupang Crowntail Black Orchid', 'Cupang Plakat Platinum', 'Cupang Halfmoon Big Ear']

# %%
X = []
Z = []
Crowntail_Black_Orchid_dir = "/content/dataset/val/Cupang Crowntail Black Orchid"
Crowntail_Super_Red_dir = "/content/dataset/val/Cupang Crowntail Super Red"
Halfmoon_Big_Ear_dir = "/content/dataset/val/Cupang Halfmoon Big Ear"
Halfmoon_Blue_dir = "/content/dataset/val/Cupang Halfmoon Blue"
Halfmoon_Multicolor_dir = "/content/dataset/val/Cupang Halfmoon Multicolor"
Halfmoon_Nemo_dir = "/content/dataset/val/Cupang Halfmoon Nemo"
Halfmoon_Red_dir = "/content/dataset/val/Cupang Halfmoon Red"
Halfmoon_Red_Cooper_dir = "/content/dataset/val/Cupang Halfmoon Red Cooper"
Plakat_Blue_Rim_dir = "/content/dataset/val/Cupang Plakat Blue Rim"
Plakat_Platinum_dir = "/content/dataset/val/Cupang Plakat Platinum"

# %% [markdown]
# Mendefinisikan Fungsi untuk memasukkan image ke dalam list array

# %%
def assign_label(img, gbk): #gbk gambar ikan
    return gbk

def val_data(gbk,DIR): 
    for img in tqdm(os.listdir(DIR)):
        label= assign_label(img, gbk)
        path= os.path.join(DIR,img)
        img= cv2.imread(path,cv2.IMREAD_COLOR)
        img= cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Warna menjadi RGB
        img= cv2.resize(img, (150,150)) # ukuran gambar menjadi 150 x 150 pixel
        
        X.append(np.array(img))
        Z.append(str(label))

# %% [markdown]
# Menggabungkan data paper, rock, scissor ke dalam 1 list

# %%
val_data('Crowntail_Black_Orchid', Crowntail_Black_Orchid_dir)
print(len(X))
# Out:
# 100%|██████████| 262/262 [00:04<00:00, 56.94it/s]
# 262

# %%
val_data('Crowntail_Super_Red', Crowntail_Super_Red_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 297.22it/s]
# 525

# %%
val_data('Halfmoon_Big_Ear', Halfmoon_Big_Ear_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 337.34it/s]
# 788

# %%
val_data('Halfmoon_Blue', Halfmoon_Blue_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 309.94it/s]
# 1051

# %%
val_data('Halfmoon_Multicolor', Halfmoon_Multicolor_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 337.49it/s]
# 1314

# %%
val_data('Halfmoon_Nemo', Halfmoon_Nemo_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 323.07it/s]
# 1577

# %%
val_data('Halfmoon_Red', Halfmoon_Red_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 321.29it/s]
# 1840

# %%
val_data('Halfmoon_Red_Cooper', Halfmoon_Red_Cooper_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 347.73it/s]
# 2103

# %%
val_data('Plakat_Blue_Rim', Plakat_Blue_Rim_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 363.74it/s]
# 2366

# %%
val_data('Plakat_Platinum', Plakat_Platinum_dir)
print(len(X))
# Out:
# 100%|██████████| 263/263 [00:00<00:00, 366.67it/s]
# 2629

# %%
# Menampilkan gambar validasi dengan acak
fig,ax=plt.subplots(5,5)
fig.set_size_inches(16,16)
for i in range(5):
    for j in range (5):
        gamb=rd.randint(0,len(Z))
        ax[i,j].imshow(X[gamb])
        ax[i,j].set_title('Jenis Cupang: '+Z[gamb])
        
plt.tight_layout()

# %% [markdown]
# ## Augmentasi

# %% [markdown]
# Melakukan Augmentasi gambar untuk menciptakan data/gambar baru dari data yang telah ada

# %%
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    zoom_range = 0.1, # mengubah zoom image 
                    width_shift_range=0.1,  # mengubah image secara horizontal
                    height_shift_range=0.1, # mengubah image secara vertikal
                    #validation_split=0.15,featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False)  
                    
 
test_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True
                    )

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,  # direktori data latih
        target_size=(150, 150),  # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=12,
        class_mode='categorical') # karena ini merupakan masalah klasifikasi lebih dari 2 kelas maka menggunakan class_mode = 'categorical'
 
validation_generator = test_datagen.flow_from_directory(
        validation_dir, # direktori data validasi
        target_size=(150, 150), # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=1, 
        class_mode='categorical') # karena ini merupakan masalah klasifikasi lebih dari 2 kelas maka menggunakan class_mode = 'categorical'
# Out:
# Found 10505 images belonging to 10 classes.
# Found 2629 images belonging to 10 classes.

# %% [markdown]
# # **Modelling**

# %%
# Fungsi untuk menyimpan model
save_direc = os.path.join(os.getcwd(), '/content/sample_data')

model_name = 'cupang_weight_model2.h5'

# Create Directory if it doesn't exist
if not os.path.isdir(save_direc):
    os.makedirs(save_direc)
# Join the directory with the model file
modelpath = os.path.join(save_direc, model_name)

checkpoint = ModelCheckpoint(filepath = modelpath, verbose = 1, save_best_only = True,
                             save_weights_only = True, period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Inisialisasi class untuk menghentikan proses training apabila akurasi validasi telah diatas 95%
class myCallBack(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') >= 0.935):
      print("\nAkurasi telah mencapai >93%!")
      self.model.stop_training = True
myCallBack = myCallBack()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (5,5), padding='Same', activation='relu',  input_shape=(150, 150, 3)),
    tf.keras.layers.Conv2D(32, (5,5), padding='Same', activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (5,5), padding='Same', activation='relu'),
    tf.keras.layers.Conv2D(64, (3,3), padding='Same', activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), # mereduksi resolusi gambar
    tf.keras.layers.Dropout(0.2), # agar model tidak overfitting

    tf.keras.layers.Conv2D(128, (3,3), padding='Same', activation='relu'),
    tf.keras.layers.Conv2D(128, (3,3), padding='Same', activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), # mereduksi resolusi gambar
    tf.keras.layers.Dropout(0.3), # agar model tidak overfitting

    tf.keras.layers.Conv2D(256, (3,3), padding='Same', activation='relu'),
    tf.keras.layers.Conv2D(256, (3,3), padding='Same', activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), # mereduksi resolusi gambar
    tf.keras.layers.Dropout(0.3), # agar model tidak overfitting

    tf.keras.layers.Flatten(),  
    tf.keras.layers.Dense(512, kernel_regularizer=regularizers.l2(0.001), activation='relu'), # Hidden layer
    tf.keras.layers.Dropout(0.5), # agar model tidak overfitting
    tf.keras.layers.Dense(10, activation='softmax') # 3 label output lalu menggunakan softmax karena model adalah klasifikasi kategori
])

model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.RMSprop(learning_rate=0.0001), #Menggunakan optimizer rmsprop
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      2432
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      25632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        51264
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 18, 18, 256)       590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 20736)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               10617344
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 11,845,418
# Trainable params: 11,845,418
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist=model.fit(
      train_generator,
      steps_per_epoch=35,  # berapa batch yang akan dieksekusi pada setiap epoch
      epochs=300, # jumlah maksimal epoch yang akan di eksekusi
      validation_data=validation_generator, # menampilkan akurasi pengujian data validasi
      callbacks=[checkpoint, myCallBack],
      #validation_steps=5,  # berapa batch yang akan dieksekusi pada setiap epoch
      verbose=1)
# Out:
# Epoch 1/300
# 35/35 [==============================] - ETA: 0s - loss: 3.1761 - accuracy: 0.1167
# Epoch 00001: val_loss improved from inf to 3.03978, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 29s 821ms/step - loss: 3.1761 - accuracy: 0.1167 - val_loss: 3.0398 - val_accuracy: 0.1871
# Epoch 2/300
# 35/35 [==============================] - ETA: 0s - loss: 2.8085 - accuracy: 0.2024
# Epoch 00002: val_loss improved from 3.03978 to 2.57522, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 29s 825ms/step - loss: 2.8085 - accuracy: 0.2024 - val_loss: 2.5752 - val_accuracy: 0.3153
# Epoch 3/300
# 35/35 [==============================] - ETA: 0s - loss: 2.3705 - accuracy: 0.3333
# Epoch 00003: val_loss improved from 2.57522 to 2.35607, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 29s 815ms/step - loss: 2.3705 - accuracy: 0.3333 - val_loss: 2.3561 - val_accuracy: 0.3690
# Epoch 4/300
# 35/35 [==============================] - ETA: 0s - loss: 2.3641 - accuracy: 0.2952
# Epoch 00004: val_loss improved from 2.35607 to 2.18684, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 813ms/step - loss: 2.3641 - accuracy: 0.2952 - val_loss: 2.1868 - val_accuracy: 0.3868
# Epoch 5/300
# 35/35 [==============================] - ETA: 0s - loss: 2.1178 - accuracy: 0.3857
# Epoch 00005: val_loss improved from 2.18684 to 2.07889, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 813ms/step - loss: 2.1178 - accuracy: 0.3857 - val_loss: 2.0789 - val_accuracy: 0.3922
# Epoch 6/300
# 35/35 [==============================] - ETA: 0s - loss: 2.1391 - accuracy: 0.3595
# Epoch 00006: val_loss did not improve from 2.07889
# 35/35 [==============================] - 28s 809ms/step - loss: 2.1391 - accuracy: 0.3595 - val_loss: 2.0889 - val_accuracy: 0.3450
# Epoch 7/300
# 35/35 [==============================] - ETA: 0s - loss: 2.0367 - accuracy: 0.3881
# Epoch 00007: val_loss improved from 2.07889 to 1.93914, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 812ms/step - loss: 2.0367 - accuracy: 0.3881 - val_loss: 1.9391 - val_accuracy: 0.3853
# Epoch 8/300
# 35/35 [==============================] - ETA: 0s - loss: 1.9382 - accuracy: 0.4143
# Epoch 00008: val_loss improved from 1.93914 to 1.91451, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 814ms/step - loss: 1.9382 - accuracy: 0.4143 - val_loss: 1.9145 - val_accuracy: 0.4310
# Epoch 9/300
# 35/35 [==============================] - ETA: 0s - loss: 1.9791 - accuracy: 0.4119
# Epoch 00009: val_loss improved from 1.91451 to 1.68324, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 813ms/step - loss: 1.9791 - accuracy: 0.4119 - val_loss: 1.6832 - val_accuracy: 0.4758
# Epoch 10/300
# 35/35 [==============================] - ETA: 0s - loss: 1.7661 - accuracy: 0.4952
# Epoch 00010: val_loss did not improve from 1.68324
# 35/35 [==============================] - 28s 812ms/step - loss: 1.7661 - accuracy: 0.4952 - val_loss: 1.7495 - val_accuracy: 0.5242
# Epoch 11/300
# 35/35 [==============================] - ETA: 0s - loss: 1.7037 - accuracy: 0.4810
# Epoch 00011: val_loss improved from 1.68324 to 1.60319, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 29s 818ms/step - loss: 1.7037 - accuracy: 0.4810 - val_loss: 1.6032 - val_accuracy: 0.5508
# Epoch 12/300
# 35/35 [==============================] - ETA: 0s - loss: 1.6769 - accuracy: 0.4697
# Epoch 00012: val_loss improved from 1.60319 to 1.51613, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 30s 857ms/step - loss: 1.6769 - accuracy: 0.4697 - val_loss: 1.5161 - val_accuracy: 0.6010
# Epoch 13/300
# 35/35 [==============================] - ETA: 0s - loss: 1.6153 - accuracy: 0.5143
# Epoch 00013: val_loss improved from 1.51613 to 1.48689, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 29s 816ms/step - loss: 1.6153 - accuracy: 0.5143 - val_loss: 1.4869 - val_accuracy: 0.5671
# Epoch 14/300
# 35/35 [==============================] - ETA: 0s - loss: 1.5984 - accuracy: 0.5476
# Epoch 00014: val_loss improved from 1.48689 to 1.36713, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 807ms/step - loss: 1.5984 - accuracy: 0.5476 - val_loss: 1.3671 - val_accuracy: 0.6033
# Epoch 15/300
# 35/35 [==============================] - ETA: 0s - loss: 1.5856 - accuracy: 0.5595
# Epoch 00015: val_loss did not improve from 1.36713
# 35/35 [==============================] - 28s 803ms/step - loss: 1.5856 - accuracy: 0.5595 - val_loss: 1.3764 - val_accuracy: 0.6147
# Epoch 16/300
# 35/35 [==============================] - ETA: 0s - loss: 1.5139 - accuracy: 0.5357
# Epoch 00016: val_loss did not improve from 1.36713
# 35/35 [==============================] - 28s 794ms/step - loss: 1.5139 - accuracy: 0.5357 - val_loss: 1.4937 - val_accuracy: 0.5983
# Epoch 17/300
# 35/35 [==============================] - ETA: 0s - loss: 1.4549 - accuracy: 0.5762
# Epoch 00017: val_loss improved from 1.36713 to 1.36583, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 790ms/step - loss: 1.4549 - accuracy: 0.5762 - val_loss: 1.3658 - val_accuracy: 0.6124
# Epoch 18/300
# 35/35 [==============================] - ETA: 0s - loss: 1.4948 - accuracy: 0.5810
# Epoch 00018: val_loss improved from 1.36583 to 1.33936, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 788ms/step - loss: 1.4948 - accuracy: 0.5810 - val_loss: 1.3394 - val_accuracy: 0.6851
# Epoch 19/300
# 35/35 [==============================] - ETA: 0s - loss: 1.4827 - accuracy: 0.5811
# Epoch 00019: val_loss improved from 1.33936 to 1.24373, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 789ms/step - loss: 1.4827 - accuracy: 0.5811 - val_loss: 1.2437 - val_accuracy: 0.6782
# Epoch 20/300
# 35/35 [==============================] - ETA: 0s - loss: 1.3693 - accuracy: 0.5595
# Epoch 00020: val_loss improved from 1.24373 to 1.20615, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 787ms/step - loss: 1.3693 - accuracy: 0.5595 - val_loss: 1.2061 - val_accuracy: 0.6889
# Epoch 21/300
# 35/35 [==============================] - ETA: 0s - loss: 1.3510 - accuracy: 0.6476
# Epoch 00021: val_loss did not improve from 1.20615
# 35/35 [==============================] - 27s 780ms/step - loss: 1.3510 - accuracy: 0.6476 - val_loss: 1.2632 - val_accuracy: 0.6033
# Epoch 22/300
# 35/35 [==============================] - ETA: 0s - loss: 1.3647 - accuracy: 0.6119
# Epoch 00022: val_loss improved from 1.20615 to 1.18747, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 27s 785ms/step - loss: 1.3647 - accuracy: 0.6119 - val_loss: 1.1875 - val_accuracy: 0.6733
# Epoch 23/300
# 35/35 [==============================] - ETA: 0s - loss: 1.3280 - accuracy: 0.6262
# Epoch 00023: val_loss improved from 1.18747 to 1.13005, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 28s 795ms/step - loss: 1.3280 - accuracy: 0.6262 - val_loss: 1.1301 - val_accuracy: 0.6763
# Epoch 24/300
# 35/35 [==============================] - ETA: 0s - loss: 1.1999 - accuracy: 0.6476
# Epoch 00024: val_loss did not improve from 1.13005
# 35/35 [==============================] - 27s 768ms/step - loss: 1.1999 - accuracy: 0.6476 - val_loss: 1.2308 - val_accuracy: 0.6733
# Epoch 25/300
# 35/35 [==============================] - ETA: 0s - loss: 1.3688 - accuracy: 0.6190
# Epoch 00025: val_loss improved from 1.13005 to 1.09610, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 27s 768ms/step - loss: 1.3688 - accuracy: 0.6190 - val_loss: 1.0961 - val_accuracy: 0.7235
# Epoch 26/300
# 35/35 [==============================] - ETA: 0s - loss: 1.2495 - accuracy: 0.6286
# Epoch 00026: val_loss improved from 1.09610 to 1.03764, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 27s 759ms/step - loss: 1.2495 - accuracy: 0.6286 - val_loss: 1.0376 - val_accuracy: 0.7094
# Epoch 27/300
# 35/35 [==============================] - ETA: 0s - loss: 1.2724 - accuracy: 0.6452
# Epoch 00027: val_loss did not improve from 1.03764
# 35/35 [==============================] - 27s 759ms/step - loss: 1.2724 - accuracy: 0.6452 - val_loss: 1.0785 - val_accuracy: 0.7459
# Epoch 28/300
# 35/35 [==============================] - ETA: 0s - loss: 1.1933 - accuracy: 0.6810
# Epoch 00028: val_loss improved from 1.03764 to 1.01389, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 27s 772ms/step - loss: 1.1933 - accuracy: 0.6810 - val_loss: 1.0139 - val_accuracy: 0.7630
# Epoch 29/300
# 35/35 [==============================] - ETA: 0s - loss: 1.1611 - accuracy: 0.6810
# Epoch 00029: val_loss did not improve from 1.01389
# 35/35 [==============================] - 26s 754ms/step - loss: 1.1611 - accuracy: 0.6810 - val_loss: 1.0977 - val_accuracy: 0.7303
# Epoch 30/300
# 35/35 [==============================] - ETA: 0s - loss: 1.1043 - accuracy: 0.7310
# Epoch 00030: val_loss did not improve from 1.01389
# 35/35 [==============================] - 27s 758ms/step - loss: 1.1043 - accuracy: 0.7310 - val_loss: 1.0204 - val_accuracy: 0.7387
# Epoch 31/300
# 35/35 [==============================] - ETA: 0s - loss: 1.0189 - accuracy: 0.7262
# Epoch 00031: val_loss improved from 1.01389 to 0.92268, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 757ms/step - loss: 1.0189 - accuracy: 0.7262 - val_loss: 0.9227 - val_accuracy: 0.7741
# Epoch 32/300
# 35/35 [==============================] - ETA: 0s - loss: 1.2382 - accuracy: 0.6667
# Epoch 00032: val_loss did not improve from 0.92268
# 35/35 [==============================] - 26s 747ms/step - loss: 1.2382 - accuracy: 0.6667 - val_loss: 0.9811 - val_accuracy: 0.7623
# Epoch 33/300
# 35/35 [==============================] - ETA: 0s - loss: 1.1086 - accuracy: 0.6976
# Epoch 00033: val_loss did not improve from 0.92268
# 35/35 [==============================] - 26s 741ms/step - loss: 1.1086 - accuracy: 0.6976 - val_loss: 1.1411 - val_accuracy: 0.6778
# Epoch 34/300
# 35/35 [==============================] - ETA: 0s - loss: 1.0575 - accuracy: 0.7048
# Epoch 00034: val_loss improved from 0.92268 to 0.86054, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 754ms/step - loss: 1.0575 - accuracy: 0.7048 - val_loss: 0.8605 - val_accuracy: 0.7763
# Epoch 35/300
# 35/35 [==============================] - ETA: 0s - loss: 1.1166 - accuracy: 0.6833
# Epoch 00035: val_loss improved from 0.86054 to 0.84832, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 748ms/step - loss: 1.1166 - accuracy: 0.6833 - val_loss: 0.8483 - val_accuracy: 0.7672
# Epoch 36/300
# 35/35 [==============================] - ETA: 0s - loss: 0.9986 - accuracy: 0.7167
# Epoch 00036: val_loss improved from 0.84832 to 0.80962, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 736ms/step - loss: 0.9986 - accuracy: 0.7167 - val_loss: 0.8096 - val_accuracy: 0.7919
# Epoch 37/300
# 35/35 [==============================] - ETA: 0s - loss: 1.0313 - accuracy: 0.7071
# Epoch 00037: val_loss did not improve from 0.80962
# 35/35 [==============================] - 26s 747ms/step - loss: 1.0313 - accuracy: 0.7071 - val_loss: 0.8444 - val_accuracy: 0.7942
# Epoch 38/300
# 35/35 [==============================] - ETA: 0s - loss: 1.0444 - accuracy: 0.7333
# Epoch 00038: val_loss improved from 0.80962 to 0.80813, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 747ms/step - loss: 1.0444 - accuracy: 0.7333 - val_loss: 0.8081 - val_accuracy: 0.7931
# Epoch 39/300
# 35/35 [==============================] - ETA: 0s - loss: 1.0045 - accuracy: 0.7429
# Epoch 00039: val_loss did not improve from 0.80813
# 35/35 [==============================] - 26s 736ms/step - loss: 1.0045 - accuracy: 0.7429 - val_loss: 0.8627 - val_accuracy: 0.7706
# Epoch 40/300
# 35/35 [==============================] - ETA: 0s - loss: 0.9028 - accuracy: 0.7548
# Epoch 00040: val_loss did not improve from 0.80813
# 35/35 [==============================] - 26s 743ms/step - loss: 0.9028 - accuracy: 0.7548 - val_loss: 0.9096 - val_accuracy: 0.7391
# Epoch 41/300
# 35/35 [==============================] - ETA: 0s - loss: 1.0829 - accuracy: 0.7143
# Epoch 00041: val_loss did not improve from 0.80813
# 35/35 [==============================] - 26s 741ms/step - loss: 1.0829 - accuracy: 0.7143 - val_loss: 0.8154 - val_accuracy: 0.7760
# Epoch 42/300
# 35/35 [==============================] - ETA: 0s - loss: 0.9426 - accuracy: 0.7143
# Epoch 00042: val_loss improved from 0.80813 to 0.80037, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 738ms/step - loss: 0.9426 - accuracy: 0.7143 - val_loss: 0.8004 - val_accuracy: 0.8030
# Epoch 43/300
# 35/35 [==============================] - ETA: 0s - loss: 0.9127 - accuracy: 0.7452
# Epoch 00043: val_loss did not improve from 0.80037
# 35/35 [==============================] - 26s 745ms/step - loss: 0.9127 - accuracy: 0.7452 - val_loss: 0.8530 - val_accuracy: 0.7486
# Epoch 44/300
# 35/35 [==============================] - ETA: 0s - loss: 0.9574 - accuracy: 0.7429
# Epoch 00044: val_loss did not improve from 0.80037
# 35/35 [==============================] - 26s 739ms/step - loss: 0.9574 - accuracy: 0.7429 - val_loss: 0.8895 - val_accuracy: 0.7699
# Epoch 45/300
# 35/35 [==============================] - ETA: 0s - loss: 0.9783 - accuracy: 0.7238
# Epoch 00045: val_loss did not improve from 0.80037
# 35/35 [==============================] - 26s 743ms/step - loss: 0.9783 - accuracy: 0.7238 - val_loss: 1.2691 - val_accuracy: 0.6310
# Epoch 46/300
# 35/35 [==============================] - ETA: 0s - loss: 0.8810 - accuracy: 0.7500
# Epoch 00046: val_loss improved from 0.80037 to 0.78273, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 27s 759ms/step - loss: 0.8810 - accuracy: 0.7500 - val_loss: 0.7827 - val_accuracy: 0.7973
# Epoch 47/300
# 35/35 [==============================] - ETA: 0s - loss: 0.8278 - accuracy: 0.7738
# Epoch 00047: val_loss did not improve from 0.78273
# 35/35 [==============================] - 26s 738ms/step - loss: 0.8278 - accuracy: 0.7738 - val_loss: 0.8367 - val_accuracy: 0.7912
# Epoch 48/300
# 35/35 [==============================] - ETA: 0s - loss: 0.9290 - accuracy: 0.7500
# Epoch 00048: val_loss did not improve from 0.78273
# 35/35 [==============================] - 26s 740ms/step - loss: 0.9290 - accuracy: 0.7500 - val_loss: 0.8176 - val_accuracy: 0.7923
# Epoch 49/300
# 35/35 [==============================] - ETA: 0s - loss: 0.9096 - accuracy: 0.7524
# Epoch 00049: val_loss improved from 0.78273 to 0.72468, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 750ms/step - loss: 0.9096 - accuracy: 0.7524 - val_loss: 0.7247 - val_accuracy: 0.8163
# Epoch 50/300
# 35/35 [==============================] - ETA: 0s - loss: 0.8245 - accuracy: 0.7881
# Epoch 00050: val_loss improved from 0.72468 to 0.67063, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 746ms/step - loss: 0.8245 - accuracy: 0.7881 - val_loss: 0.6706 - val_accuracy: 0.8501
# Epoch 51/300
# 35/35 [==============================] - ETA: 0s - loss: 0.8591 - accuracy: 0.7452
# Epoch 00051: val_loss did not improve from 0.67063
# 35/35 [==============================] - 26s 737ms/step - loss: 0.8591 - accuracy: 0.7452 - val_loss: 0.7060 - val_accuracy: 0.8304
# Epoch 52/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7470 - accuracy: 0.7881
# Epoch 00052: val_loss did not improve from 0.67063
# 35/35 [==============================] - 26s 742ms/step - loss: 0.7470 - accuracy: 0.7881 - val_loss: 0.7431 - val_accuracy: 0.8148
# Epoch 53/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7711 - accuracy: 0.8214
# Epoch 00053: val_loss improved from 0.67063 to 0.66803, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 745ms/step - loss: 0.7711 - accuracy: 0.8214 - val_loss: 0.6680 - val_accuracy: 0.8395
# Epoch 54/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7706 - accuracy: 0.7881
# Epoch 00054: val_loss improved from 0.66803 to 0.64193, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 742ms/step - loss: 0.7706 - accuracy: 0.7881 - val_loss: 0.6419 - val_accuracy: 0.8364
# Epoch 55/300
# 35/35 [==============================] - ETA: 0s - loss: 0.8192 - accuracy: 0.7476
# Epoch 00055: val_loss improved from 0.64193 to 0.62048, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 750ms/step - loss: 0.8192 - accuracy: 0.7476 - val_loss: 0.6205 - val_accuracy: 0.8562
# Epoch 56/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7917 - accuracy: 0.7881
# Epoch 00056: val_loss improved from 0.62048 to 0.60411, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 27s 758ms/step - loss: 0.7917 - accuracy: 0.7881 - val_loss: 0.6041 - val_accuracy: 0.8490
# Epoch 57/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7422 - accuracy: 0.8024
# Epoch 00057: val_loss did not improve from 0.60411
# 35/35 [==============================] - 26s 748ms/step - loss: 0.7422 - accuracy: 0.8024 - val_loss: 0.6639 - val_accuracy: 0.8338
# Epoch 58/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7129 - accuracy: 0.8048
# Epoch 00058: val_loss did not improve from 0.60411
# 35/35 [==============================] - 27s 771ms/step - loss: 0.7129 - accuracy: 0.8048 - val_loss: 0.6405 - val_accuracy: 0.8501
# Epoch 59/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7784 - accuracy: 0.7952
# Epoch 00059: val_loss did not improve from 0.60411
# 35/35 [==============================] - 26s 743ms/step - loss: 0.7784 - accuracy: 0.7952 - val_loss: 0.6178 - val_accuracy: 0.8517
# Epoch 60/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7414 - accuracy: 0.8095
# Epoch 00060: val_loss did not improve from 0.60411
# 35/35 [==============================] - 26s 754ms/step - loss: 0.7414 - accuracy: 0.8095 - val_loss: 0.6795 - val_accuracy: 0.8266
# Epoch 61/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7609 - accuracy: 0.7976
# Epoch 00061: val_loss did not improve from 0.60411
# 35/35 [==============================] - 27s 758ms/step - loss: 0.7609 - accuracy: 0.7976 - val_loss: 0.6381 - val_accuracy: 0.8250
# Epoch 62/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7463 - accuracy: 0.7905
# Epoch 00062: val_loss improved from 0.60411 to 0.55903, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 751ms/step - loss: 0.7463 - accuracy: 0.7905 - val_loss: 0.5590 - val_accuracy: 0.8676
# Epoch 63/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7351 - accuracy: 0.8214
# Epoch 00063: val_loss did not improve from 0.55903
# 35/35 [==============================] - 26s 746ms/step - loss: 0.7351 - accuracy: 0.8214 - val_loss: 0.6325 - val_accuracy: 0.8300
# Epoch 64/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7578 - accuracy: 0.8119
# Epoch 00064: val_loss did not improve from 0.55903
# 35/35 [==============================] - 26s 748ms/step - loss: 0.7578 - accuracy: 0.8119 - val_loss: 0.6021 - val_accuracy: 0.8448
# Epoch 65/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7123 - accuracy: 0.7905
# Epoch 00065: val_loss did not improve from 0.55903
# 35/35 [==============================] - 26s 745ms/step - loss: 0.7123 - accuracy: 0.7905 - val_loss: 0.6187 - val_accuracy: 0.8334
# Epoch 66/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7602 - accuracy: 0.8071
# Epoch 00066: val_loss improved from 0.55903 to 0.54398, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 743ms/step - loss: 0.7602 - accuracy: 0.8071 - val_loss: 0.5440 - val_accuracy: 0.8653
# Epoch 67/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6543 - accuracy: 0.8238
# Epoch 00067: val_loss improved from 0.54398 to 0.51444, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 749ms/step - loss: 0.6543 - accuracy: 0.8238 - val_loss: 0.5144 - val_accuracy: 0.8760
# Epoch 68/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7082 - accuracy: 0.7976
# Epoch 00068: val_loss did not improve from 0.51444
# 35/35 [==============================] - 26s 744ms/step - loss: 0.7082 - accuracy: 0.7976 - val_loss: 0.5321 - val_accuracy: 0.8634
# Epoch 69/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6733 - accuracy: 0.8238
# Epoch 00069: val_loss did not improve from 0.51444
# 35/35 [==============================] - 26s 736ms/step - loss: 0.6733 - accuracy: 0.8238 - val_loss: 0.8000 - val_accuracy: 0.7916
# Epoch 70/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6611 - accuracy: 0.7952
# Epoch 00070: val_loss did not improve from 0.51444
# 35/35 [==============================] - 26s 748ms/step - loss: 0.6611 - accuracy: 0.7952 - val_loss: 0.7360 - val_accuracy: 0.8132
# Epoch 71/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6814 - accuracy: 0.8167
# Epoch 00071: val_loss did not improve from 0.51444
# 35/35 [==============================] - 26s 737ms/step - loss: 0.6814 - accuracy: 0.8167 - val_loss: 0.8305 - val_accuracy: 0.7820
# Epoch 72/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6389 - accuracy: 0.8429
# Epoch 00072: val_loss did not improve from 0.51444
# 35/35 [==============================] - 26s 731ms/step - loss: 0.6389 - accuracy: 0.8429 - val_loss: 0.5682 - val_accuracy: 0.8528
# Epoch 73/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6656 - accuracy: 0.8357
# Epoch 00073: val_loss did not improve from 0.51444
# 35/35 [==============================] - 26s 737ms/step - loss: 0.6656 - accuracy: 0.8357 - val_loss: 0.7139 - val_accuracy: 0.8167
# Epoch 74/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7021 - accuracy: 0.7952
# Epoch 00074: val_loss did not improve from 0.51444
# 35/35 [==============================] - 26s 753ms/step - loss: 0.7021 - accuracy: 0.7952 - val_loss: 0.5490 - val_accuracy: 0.8688
# Epoch 75/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6579 - accuracy: 0.8143
# Epoch 00075: val_loss improved from 0.51444 to 0.50393, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 753ms/step - loss: 0.6579 - accuracy: 0.8143 - val_loss: 0.5039 - val_accuracy: 0.8768
# Epoch 76/300
# 35/35 [==============================] - ETA: 0s - loss: 0.7387 - accuracy: 0.8095
# Epoch 00076: val_loss improved from 0.50393 to 0.47321, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 748ms/step - loss: 0.7387 - accuracy: 0.8095 - val_loss: 0.4732 - val_accuracy: 0.8806
# Epoch 77/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6377 - accuracy: 0.8500
# Epoch 00077: val_loss did not improve from 0.47321
# 35/35 [==============================] - 26s 746ms/step - loss: 0.6377 - accuracy: 0.8500 - val_loss: 0.5261 - val_accuracy: 0.8650
# Epoch 78/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6221 - accuracy: 0.8354
# Epoch 00078: val_loss did not improve from 0.47321
# 35/35 [==============================] - 26s 755ms/step - loss: 0.6221 - accuracy: 0.8354 - val_loss: 0.5183 - val_accuracy: 0.8809
# Epoch 79/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6168 - accuracy: 0.8333
# Epoch 00079: val_loss improved from 0.47321 to 0.46453, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 750ms/step - loss: 0.6168 - accuracy: 0.8333 - val_loss: 0.4645 - val_accuracy: 0.8870
# Epoch 80/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6706 - accuracy: 0.8024
# Epoch 00080: val_loss improved from 0.46453 to 0.43615, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 754ms/step - loss: 0.6706 - accuracy: 0.8024 - val_loss: 0.4362 - val_accuracy: 0.9026
# Epoch 81/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5842 - accuracy: 0.8405
# Epoch 00081: val_loss did not improve from 0.43615
# 35/35 [==============================] - 27s 766ms/step - loss: 0.5842 - accuracy: 0.8405 - val_loss: 0.5049 - val_accuracy: 0.8661
# Epoch 82/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5936 - accuracy: 0.8310
# Epoch 00082: val_loss did not improve from 0.43615
# 35/35 [==============================] - 28s 787ms/step - loss: 0.5936 - accuracy: 0.8310 - val_loss: 0.4783 - val_accuracy: 0.8783
# Epoch 83/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5848 - accuracy: 0.8310
# Epoch 00083: val_loss did not improve from 0.43615
# 35/35 [==============================] - 27s 767ms/step - loss: 0.5848 - accuracy: 0.8310 - val_loss: 0.4608 - val_accuracy: 0.8787
# Epoch 84/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5598 - accuracy: 0.8595
# Epoch 00084: val_loss did not improve from 0.43615
# 35/35 [==============================] - 26s 756ms/step - loss: 0.5598 - accuracy: 0.8595 - val_loss: 0.5403 - val_accuracy: 0.8741
# Epoch 85/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.8381
# Epoch 00085: val_loss improved from 0.43615 to 0.41812, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 753ms/step - loss: 0.6263 - accuracy: 0.8381 - val_loss: 0.4181 - val_accuracy: 0.9015
# Epoch 86/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5794 - accuracy: 0.8381
# Epoch 00086: val_loss did not improve from 0.41812
# 35/35 [==============================] - 27s 759ms/step - loss: 0.5794 - accuracy: 0.8381 - val_loss: 0.4189 - val_accuracy: 0.9095
# Epoch 87/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6222 - accuracy: 0.8357
# Epoch 00087: val_loss did not improve from 0.41812
# 35/35 [==============================] - 26s 749ms/step - loss: 0.6222 - accuracy: 0.8357 - val_loss: 0.4290 - val_accuracy: 0.9068
# Epoch 88/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6005 - accuracy: 0.8333
# Epoch 00088: val_loss did not improve from 0.41812
# 35/35 [==============================] - 26s 740ms/step - loss: 0.6005 - accuracy: 0.8333 - val_loss: 0.5837 - val_accuracy: 0.8547
# Epoch 89/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5581 - accuracy: 0.8500
# Epoch 00089: val_loss improved from 0.41812 to 0.38974, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 746ms/step - loss: 0.5581 - accuracy: 0.8500 - val_loss: 0.3897 - val_accuracy: 0.9129
# Epoch 90/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5806 - accuracy: 0.8329
# Epoch 00090: val_loss did not improve from 0.38974
# 35/35 [==============================] - 26s 733ms/step - loss: 0.5806 - accuracy: 0.8329 - val_loss: 0.3994 - val_accuracy: 0.9068
# Epoch 91/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6259 - accuracy: 0.8381
# Epoch 00091: val_loss did not improve from 0.38974
# 35/35 [==============================] - 26s 740ms/step - loss: 0.6259 - accuracy: 0.8381 - val_loss: 0.4410 - val_accuracy: 0.8969
# Epoch 92/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5287 - accuracy: 0.8717
# Epoch 00092: val_loss did not improve from 0.38974
# 35/35 [==============================] - 26s 740ms/step - loss: 0.5287 - accuracy: 0.8717 - val_loss: 0.4219 - val_accuracy: 0.9015
# Epoch 93/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5616 - accuracy: 0.8405
# Epoch 00093: val_loss did not improve from 0.38974
# 35/35 [==============================] - 26s 740ms/step - loss: 0.5616 - accuracy: 0.8405 - val_loss: 0.4463 - val_accuracy: 0.9011
# Epoch 94/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6284 - accuracy: 0.8310
# Epoch 00094: val_loss did not improve from 0.38974
# 35/35 [==============================] - 26s 743ms/step - loss: 0.6284 - accuracy: 0.8310 - val_loss: 0.4430 - val_accuracy: 0.8935
# Epoch 95/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5299 - accuracy: 0.8667
# Epoch 00095: val_loss did not improve from 0.38974
# 35/35 [==============================] - 26s 733ms/step - loss: 0.5299 - accuracy: 0.8667 - val_loss: 0.4042 - val_accuracy: 0.8962
# Epoch 96/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5334 - accuracy: 0.8881
# Epoch 00096: val_loss improved from 0.38974 to 0.37271, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 25s 726ms/step - loss: 0.5334 - accuracy: 0.8881 - val_loss: 0.3727 - val_accuracy: 0.9129
# Epoch 97/300
# 35/35 [==============================] - ETA: 0s - loss: 0.6273 - accuracy: 0.8452
# Epoch 00097: val_loss did not improve from 0.37271
# 35/35 [==============================] - 26s 731ms/step - loss: 0.6273 - accuracy: 0.8452 - val_loss: 0.5702 - val_accuracy: 0.8604
# Epoch 98/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.8833
# Epoch 00098: val_loss did not improve from 0.37271
# 35/35 [==============================] - 26s 736ms/step - loss: 0.4604 - accuracy: 0.8833 - val_loss: 0.4573 - val_accuracy: 0.8878
# Epoch 99/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5817 - accuracy: 0.8786
# Epoch 00099: val_loss improved from 0.37271 to 0.35812, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 732ms/step - loss: 0.5817 - accuracy: 0.8786 - val_loss: 0.3581 - val_accuracy: 0.9053
# Epoch 100/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5622 - accuracy: 0.8286
# Epoch 00100: val_loss did not improve from 0.35812
# 35/35 [==============================] - 26s 731ms/step - loss: 0.5622 - accuracy: 0.8286 - val_loss: 0.3931 - val_accuracy: 0.9079
# Epoch 101/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4631 - accuracy: 0.8952
# Epoch 00101: val_loss did not improve from 0.35812
# 35/35 [==============================] - 25s 727ms/step - loss: 0.4631 - accuracy: 0.8952 - val_loss: 0.5529 - val_accuracy: 0.8406
# Epoch 102/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4335 - accuracy: 0.9024
# Epoch 00102: val_loss did not improve from 0.35812
# 35/35 [==============================] - 26s 730ms/step - loss: 0.4335 - accuracy: 0.9024 - val_loss: 0.3947 - val_accuracy: 0.8946
# Epoch 103/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4330 - accuracy: 0.8905
# Epoch 00103: val_loss did not improve from 0.35812
# 35/35 [==============================] - 26s 729ms/step - loss: 0.4330 - accuracy: 0.8905 - val_loss: 0.4949 - val_accuracy: 0.8783
# Epoch 104/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5573 - accuracy: 0.8524
# Epoch 00104: val_loss did not improve from 0.35812
# 35/35 [==============================] - 26s 733ms/step - loss: 0.5573 - accuracy: 0.8524 - val_loss: 0.4470 - val_accuracy: 0.8920
# Epoch 105/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5382 - accuracy: 0.8786
# Epoch 00105: val_loss improved from 0.35812 to 0.35505, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 734ms/step - loss: 0.5382 - accuracy: 0.8786 - val_loss: 0.3551 - val_accuracy: 0.9140
# Epoch 106/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4671 - accuracy: 0.8833
# Epoch 00106: val_loss did not improve from 0.35505
# 35/35 [==============================] - 26s 745ms/step - loss: 0.4671 - accuracy: 0.8833 - val_loss: 0.9493 - val_accuracy: 0.7733
# Epoch 107/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5668 - accuracy: 0.8548
# Epoch 00107: val_loss did not improve from 0.35505
# 35/35 [==============================] - 26s 734ms/step - loss: 0.5668 - accuracy: 0.8548 - val_loss: 0.4297 - val_accuracy: 0.8943
# Epoch 108/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4131 - accuracy: 0.8929
# Epoch 00108: val_loss did not improve from 0.35505
# 35/35 [==============================] - 26s 737ms/step - loss: 0.4131 - accuracy: 0.8929 - val_loss: 0.3574 - val_accuracy: 0.9220
# Epoch 109/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.8762
# Epoch 00109: val_loss improved from 0.35505 to 0.32527, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 25s 728ms/step - loss: 0.4900 - accuracy: 0.8762 - val_loss: 0.3253 - val_accuracy: 0.9308
# Epoch 110/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5445 - accuracy: 0.8571
# Epoch 00110: val_loss did not improve from 0.32527
# 35/35 [==============================] - 25s 725ms/step - loss: 0.5445 - accuracy: 0.8571 - val_loss: 0.3342 - val_accuracy: 0.9304
# Epoch 111/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5167 - accuracy: 0.8548
# Epoch 00111: val_loss did not improve from 0.32527
# 35/35 [==============================] - 25s 727ms/step - loss: 0.5167 - accuracy: 0.8548 - val_loss: 0.3267 - val_accuracy: 0.9197
# Epoch 112/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5358 - accuracy: 0.8500
# Epoch 00112: val_loss did not improve from 0.32527
# 35/35 [==============================] - 25s 723ms/step - loss: 0.5358 - accuracy: 0.8500 - val_loss: 0.3684 - val_accuracy: 0.9087
# Epoch 113/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4194 - accuracy: 0.8762
# Epoch 00113: val_loss did not improve from 0.32527
# 35/35 [==============================] - 25s 723ms/step - loss: 0.4194 - accuracy: 0.8762 - val_loss: 0.3637 - val_accuracy: 0.9068
# Epoch 114/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4103 - accuracy: 0.8881
# Epoch 00114: val_loss did not improve from 0.32527
# 35/35 [==============================] - 25s 724ms/step - loss: 0.4103 - accuracy: 0.8881 - val_loss: 0.3315 - val_accuracy: 0.9334
# Epoch 115/300
# 35/35 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.8690
# Epoch 00115: val_loss did not improve from 0.32527
# 35/35 [==============================] - 25s 721ms/step - loss: 0.5009 - accuracy: 0.8690 - val_loss: 0.3814 - val_accuracy: 0.9041
# Epoch 116/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.8762
# Epoch 00116: val_loss did not improve from 0.32527
# 35/35 [==============================] - 25s 727ms/step - loss: 0.4667 - accuracy: 0.8762 - val_loss: 0.3579 - val_accuracy: 0.9156
# Epoch 117/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4553 - accuracy: 0.8810
# Epoch 00117: val_loss did not improve from 0.32527
# 35/35 [==============================] - 25s 726ms/step - loss: 0.4553 - accuracy: 0.8810 - val_loss: 0.3271 - val_accuracy: 0.9323
# Epoch 118/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4905 - accuracy: 0.8810
# Epoch 00118: val_loss improved from 0.32527 to 0.31996, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 744ms/step - loss: 0.4905 - accuracy: 0.8810 - val_loss: 0.3200 - val_accuracy: 0.9304
# Epoch 119/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4204 - accuracy: 0.8833
# Epoch 00119: val_loss did not improve from 0.31996
# 35/35 [==============================] - 26s 732ms/step - loss: 0.4204 - accuracy: 0.8833 - val_loss: 0.4088 - val_accuracy: 0.8988
# Epoch 120/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4925 - accuracy: 0.8690
# Epoch 00120: val_loss did not improve from 0.31996
# 35/35 [==============================] - 25s 724ms/step - loss: 0.4925 - accuracy: 0.8690 - val_loss: 0.3329 - val_accuracy: 0.9273
# Epoch 121/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4127 - accuracy: 0.8952
# Epoch 00121: val_loss improved from 0.31996 to 0.29173, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 25s 722ms/step - loss: 0.4127 - accuracy: 0.8952 - val_loss: 0.2917 - val_accuracy: 0.9323
# Epoch 122/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.8786
# Epoch 00122: val_loss did not improve from 0.29173
# 35/35 [==============================] - 25s 728ms/step - loss: 0.4495 - accuracy: 0.8786 - val_loss: 0.3615 - val_accuracy: 0.9220
# Epoch 123/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4989 - accuracy: 0.8810
# Epoch 00123: val_loss did not improve from 0.29173
# 35/35 [==============================] - 26s 730ms/step - loss: 0.4989 - accuracy: 0.8810 - val_loss: 0.3230 - val_accuracy: 0.9194
# Epoch 124/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.9048
# Epoch 00124: val_loss did not improve from 0.29173
# 35/35 [==============================] - 25s 723ms/step - loss: 0.4215 - accuracy: 0.9048 - val_loss: 0.4111 - val_accuracy: 0.8908
# Epoch 125/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4828 - accuracy: 0.8881
# Epoch 00125: val_loss improved from 0.29173 to 0.27427, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 25s 723ms/step - loss: 0.4828 - accuracy: 0.8881 - val_loss: 0.2743 - val_accuracy: 0.9486
# Epoch 126/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4585 - accuracy: 0.8810
# Epoch 00126: val_loss did not improve from 0.27427
# 35/35 [==============================] - 25s 726ms/step - loss: 0.4585 - accuracy: 0.8810 - val_loss: 0.2933 - val_accuracy: 0.9391
# Epoch 127/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.8952
# Epoch 00127: val_loss improved from 0.27427 to 0.27394, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 25s 728ms/step - loss: 0.4059 - accuracy: 0.8952 - val_loss: 0.2739 - val_accuracy: 0.9391
# Epoch 128/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3976 - accuracy: 0.8929
# Epoch 00128: val_loss did not improve from 0.27394
# 35/35 [==============================] - 25s 728ms/step - loss: 0.3976 - accuracy: 0.8929 - val_loss: 0.3146 - val_accuracy: 0.9296
# Epoch 129/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4914 - accuracy: 0.8833
# Epoch 00129: val_loss improved from 0.27394 to 0.25595, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 731ms/step - loss: 0.4914 - accuracy: 0.8833 - val_loss: 0.2560 - val_accuracy: 0.9433
# Epoch 130/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.8905
# Epoch 00130: val_loss did not improve from 0.25595
# 35/35 [==============================] - 26s 744ms/step - loss: 0.4636 - accuracy: 0.8905 - val_loss: 0.2930 - val_accuracy: 0.9216
# Epoch 131/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4486 - accuracy: 0.8738
# Epoch 00131: val_loss did not improve from 0.25595
# 35/35 [==============================] - 25s 726ms/step - loss: 0.4486 - accuracy: 0.8738 - val_loss: 0.3541 - val_accuracy: 0.9182
# Epoch 132/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4401 - accuracy: 0.8741
# Epoch 00132: val_loss did not improve from 0.25595
# 35/35 [==============================] - 25s 722ms/step - loss: 0.4401 - accuracy: 0.8741 - val_loss: 0.2762 - val_accuracy: 0.9361
# Epoch 133/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.8762
# Epoch 00133: val_loss did not improve from 0.25595
# 35/35 [==============================] - 26s 729ms/step - loss: 0.4600 - accuracy: 0.8762 - val_loss: 0.3890 - val_accuracy: 0.9041
# Epoch 134/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8833
# Epoch 00134: val_loss did not improve from 0.25595
# 35/35 [==============================] - 25s 723ms/step - loss: 0.4246 - accuracy: 0.8833 - val_loss: 0.2909 - val_accuracy: 0.9323
# Epoch 135/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.9056
# Epoch 00135: val_loss did not improve from 0.25595
# 35/35 [==============================] - 25s 724ms/step - loss: 0.3586 - accuracy: 0.9056 - val_loss: 0.2719 - val_accuracy: 0.9391
# Epoch 136/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3910 - accuracy: 0.8976
# Epoch 00136: val_loss did not improve from 0.25595
# 35/35 [==============================] - 25s 728ms/step - loss: 0.3910 - accuracy: 0.8976 - val_loss: 0.2806 - val_accuracy: 0.9486
# Epoch 137/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4223 - accuracy: 0.8786
# Epoch 00137: val_loss did not improve from 0.25595
# 35/35 [==============================] - 25s 722ms/step - loss: 0.4223 - accuracy: 0.8786 - val_loss: 0.2579 - val_accuracy: 0.9384
# Epoch 138/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3361 - accuracy: 0.9262
# Epoch 00138: val_loss did not improve from 0.25595
# 35/35 [==============================] - 25s 726ms/step - loss: 0.3361 - accuracy: 0.9262 - val_loss: 0.2746 - val_accuracy: 0.9293
# Epoch 139/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4319 - accuracy: 0.8881
# Epoch 00139: val_loss did not improve from 0.25595
# 35/35 [==============================] - 26s 731ms/step - loss: 0.4319 - accuracy: 0.8881 - val_loss: 0.2923 - val_accuracy: 0.9293
# Epoch 140/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.8857
# Epoch 00140: val_loss did not improve from 0.25595
# 35/35 [==============================] - 25s 727ms/step - loss: 0.3989 - accuracy: 0.8857 - val_loss: 0.3187 - val_accuracy: 0.9144
# Epoch 141/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4201 - accuracy: 0.9048
# Epoch 00141: val_loss improved from 0.25595 to 0.25258, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 25s 724ms/step - loss: 0.4201 - accuracy: 0.9048 - val_loss: 0.2526 - val_accuracy: 0.9525
# Epoch 142/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4129 - accuracy: 0.8983
# Epoch 00142: val_loss did not improve from 0.25258
# 35/35 [==============================] - 26s 745ms/step - loss: 0.4129 - accuracy: 0.8983 - val_loss: 0.3203 - val_accuracy: 0.9258
# Epoch 143/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.9333
# Epoch 00143: val_loss did not improve from 0.25258
# 35/35 [==============================] - 25s 727ms/step - loss: 0.3293 - accuracy: 0.9333 - val_loss: 0.2755 - val_accuracy: 0.9361
# Epoch 144/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4499 - accuracy: 0.8881
# Epoch 00144: val_loss improved from 0.25258 to 0.24041, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 25s 728ms/step - loss: 0.4499 - accuracy: 0.8881 - val_loss: 0.2404 - val_accuracy: 0.9506
# Epoch 145/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4022 - accuracy: 0.8952
# Epoch 00145: val_loss improved from 0.24041 to 0.23888, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 736ms/step - loss: 0.4022 - accuracy: 0.8952 - val_loss: 0.2389 - val_accuracy: 0.9471
# Epoch 146/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3967 - accuracy: 0.9024
# Epoch 00146: val_loss did not improve from 0.23888
# 35/35 [==============================] - 26s 731ms/step - loss: 0.3967 - accuracy: 0.9024 - val_loss: 0.2422 - val_accuracy: 0.9441
# Epoch 147/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.8905
# Epoch 00147: val_loss improved from 0.23888 to 0.21658, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 731ms/step - loss: 0.4128 - accuracy: 0.8905 - val_loss: 0.2166 - val_accuracy: 0.9585
# Epoch 148/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3026 - accuracy: 0.9167
# Epoch 00148: val_loss did not improve from 0.21658
# 35/35 [==============================] - 26s 738ms/step - loss: 0.3026 - accuracy: 0.9167 - val_loss: 0.2834 - val_accuracy: 0.9365
# Epoch 149/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.9000
# Epoch 00149: val_loss improved from 0.21658 to 0.20712, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 734ms/step - loss: 0.4042 - accuracy: 0.9000 - val_loss: 0.2071 - val_accuracy: 0.9578
# Epoch 150/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3693 - accuracy: 0.8929
# Epoch 00150: val_loss did not improve from 0.20712
# 35/35 [==============================] - 25s 728ms/step - loss: 0.3693 - accuracy: 0.8929 - val_loss: 0.3262 - val_accuracy: 0.9114
# Epoch 151/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3605 - accuracy: 0.9024
# Epoch 00151: val_loss did not improve from 0.20712
# 35/35 [==============================] - 26s 732ms/step - loss: 0.3605 - accuracy: 0.9024 - val_loss: 0.2704 - val_accuracy: 0.9293
# Epoch 152/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3648 - accuracy: 0.9071
# Epoch 00152: val_loss did not improve from 0.20712
# 35/35 [==============================] - 26s 739ms/step - loss: 0.3648 - accuracy: 0.9071 - val_loss: 0.2341 - val_accuracy: 0.9441
# Epoch 153/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3511 - accuracy: 0.9048
# Epoch 00153: val_loss did not improve from 0.20712
# 35/35 [==============================] - 25s 727ms/step - loss: 0.3511 - accuracy: 0.9048 - val_loss: 0.2348 - val_accuracy: 0.9517
# Epoch 154/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3486 - accuracy: 0.9190
# Epoch 00154: val_loss did not improve from 0.20712
# 35/35 [==============================] - 26s 746ms/step - loss: 0.3486 - accuracy: 0.9190 - val_loss: 0.2326 - val_accuracy: 0.9494
# Epoch 155/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3577 - accuracy: 0.8929
# Epoch 00155: val_loss did not improve from 0.20712
# 35/35 [==============================] - 26s 739ms/step - loss: 0.3577 - accuracy: 0.8929 - val_loss: 0.2794 - val_accuracy: 0.9273
# Epoch 156/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4154 - accuracy: 0.8929
# Epoch 00156: val_loss did not improve from 0.20712
# 35/35 [==============================] - 26s 736ms/step - loss: 0.4154 - accuracy: 0.8929 - val_loss: 0.2201 - val_accuracy: 0.9490
# Epoch 157/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4224 - accuracy: 0.9000
# Epoch 00157: val_loss improved from 0.20712 to 0.20124, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 745ms/step - loss: 0.4224 - accuracy: 0.9000 - val_loss: 0.2012 - val_accuracy: 0.9661
# Epoch 158/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3738 - accuracy: 0.8952
# Epoch 00158: val_loss did not improve from 0.20124
# 35/35 [==============================] - 26s 741ms/step - loss: 0.3738 - accuracy: 0.8952 - val_loss: 0.2522 - val_accuracy: 0.9369
# Epoch 159/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3510 - accuracy: 0.9095
# Epoch 00159: val_loss did not improve from 0.20124
# 35/35 [==============================] - 26s 736ms/step - loss: 0.3510 - accuracy: 0.9095 - val_loss: 0.2485 - val_accuracy: 0.9426
# Epoch 160/300
# 35/35 [==============================] - ETA: 0s - loss: 0.4069 - accuracy: 0.8929
# Epoch 00160: val_loss did not improve from 0.20124
# 35/35 [==============================] - 26s 743ms/step - loss: 0.4069 - accuracy: 0.8929 - val_loss: 0.2332 - val_accuracy: 0.9506
# Epoch 161/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.9286
# Epoch 00161: val_loss did not improve from 0.20124
# 35/35 [==============================] - 26s 742ms/step - loss: 0.3160 - accuracy: 0.9286 - val_loss: 0.2330 - val_accuracy: 0.9410
# Epoch 162/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3671 - accuracy: 0.9071
# Epoch 00162: val_loss did not improve from 0.20124
# 35/35 [==============================] - 26s 738ms/step - loss: 0.3671 - accuracy: 0.9071 - val_loss: 0.2357 - val_accuracy: 0.9414
# Epoch 163/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.9000
# Epoch 00163: val_loss improved from 0.20124 to 0.18911, saving model to /content/sample_data/cupang_weight_model2.h5
# 35/35 [==============================] - 26s 741ms/step - loss: 0.3409 - accuracy: 0.9000 - val_loss: 0.1891 - val_accuracy: 0.9654
# Epoch 164/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3564 - accuracy: 0.9214
# Epoch 00164: val_loss did not improve from 0.18911
# 35/35 [==============================] - 26s 751ms/step - loss: 0.3564 - accuracy: 0.9214 - val_loss: 0.2125 - val_accuracy: 0.9566
# Epoch 165/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3198 - accuracy: 0.9167
# Epoch 00165: val_loss did not improve from 0.18911
# 35/35 [==============================] - 26s 743ms/step - loss: 0.3198 - accuracy: 0.9167 - val_loss: 0.2087 - val_accuracy: 0.9555
# Epoch 166/300
# 35/35 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.9262
# Epoch 00166: val_loss did not improve from 0.18911
# 35/35 [==============================] - 27s 761ms/step - loss: 0.2753 - accuracy: 0.9262 - val_loss: 0.1967 - val_accuracy: 0.9559
# Epoch 167/300
# 35/35 [==============================] - ETA: 0s - loss: 0.3108 - accuracy: 0.9357
# Epoch 00167: val_loss did not improve from 0.18911
#
# Akurasi telah mencapai >93%!
# 35/35 [==============================] - 26s 746ms/step - loss: 0.3108 - accuracy: 0.9357 - val_loss: 0.2878 - val_accuracy: 0.9300

# %%
# Menampilkan plot loss dari model
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Menampilkan plot akurasi dari model
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# Model Tensorflow yang sudah di training di-convert menjadi tflite menggunakan TFLiteConverter.

# %%
saved_model_dir = 'save/model_tflite/' # Membuat directory untuk menuimpan model
tf.saved_model.save(model, saved_model_dir) # Menyimpan model

converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir) # Konversi model menjadi tflite
tflite_model = converter.convert()

with open('model.tflite', 'wb') as f: # Membuat model tflite ke dalam directory
  f.write(tflite_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: save/model_tflite/assets

# %% [markdown]
# Sehingga model tflite akan terlihat seperti ini:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Membuat Label untuk kelas klasifikasi

# %%
print (train_generator.class_indices)

labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('labels.txt', 'w') as f:
  f.write(labels)
# Out:
# {'Cupang Crowntail Black Orchid': 0, 'Cupang Crowntail Super Red': 1, 'Cupang Halfmoon Big Ear': 2, 'Cupang Halfmoon Blue': 3, 'Cupang Halfmoon Multicolor': 4, 'Cupang Halfmoon Nemo': 5, 'Cupang Halfmoon Red': 6, 'Cupang Halfmoon Red Cooper': 7, 'Cupang Plakat Blue Rim': 8, 'Cupang Plakat Platinum': 9}

# %%
# !cat labels.txt # Melihat isi file label berformat txt yang telah dibuat
# Out:
# Cupang Crowntail Black Orchid
# Cupang Crowntail Super Red
# Cupang Halfmoon Big Ear
# Cupang Halfmoon Blue
# Cupang Halfmoon Multicolor
# Cupang Halfmoon Nemo
# Cupang Halfmoon Red
# Cupang Halfmoon Red Cooper
# Cupang Plakat Blue Rim
# Cupang Plakat Platinum

# %%
# Membuat dictionary
dic = {'Crowntail_Black_Orchid': '0', 'Crowntail_Super_Red': '1', 'Halfmoon_Big_Ear': '2', 'Halfmoon_Blue': '3', 'Halfmoon_Multicolor': '4', 'Halfmoon_Nemo': '5',
       'Halfmoon_Red': '6', 'Halfmoon_Red_Cooper': '7', 'Plakat_Blue_Rim': '8', 'Plakat_Platinum': '9'}
Z2 = [dic.get(n, n) for n in Z]

# %% [markdown]
# Melabelkan array yang sudah ada di list array

# %%
# Melabelkan list Y menjadi 10 kategori
le= LabelEncoder()
Y= le.fit_transform(Z2)
Y= to_categorical(Y,10)

# Merubah List X menjadi Array lalu menormalisasikannya
X_test= np.array(X)
X_test= X_test/255

# %% [markdown]
# Evaluasi Model dengan Confusion Matrix, Precision, Recall & F1-Score

# %%
#Mengevaluasi model dengan confussion matrix

pred= model.predict(X_test)
y_pred= np.argmax(pred, axis=1)
y_true= np.argmax(Y, axis=1)
cm = confusion_matrix(y_true, y_pred)

f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(cm, annot=True, fmt=".0f", ax=ax)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# Evaluasi model dengan precision, recall & f1-score
from sklearn.metrics import classification_report
print (classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98       262
#            1       0.96      1.00      0.98       263
#            2       1.00      0.76      0.87       263
#            3       0.94      0.91      0.93       263
#            4       0.95      0.95      0.95       263
#            5       0.93      0.94      0.93       263
#            6       0.98      0.92      0.95       263
#            7       0.99      1.00      0.99       263
#            8       0.76      1.00      0.87       263
#            9       0.90      0.90      0.90       263
#
#     accuracy                           0.93      2629
#    macro avg       0.94      0.93      0.93      2629
# weighted avg       0.94      0.93      0.93      2629

# %% [markdown]
# # **Prediksi Model**

# %%
dict_label = {0:'Crowntail_Black_Orchid', 1:'Crowntail_Super_Red', 2:'Halfmoon_Big_Ear', 
              3:'Halfmoon_Blue', 4:'Halfmoon_Multicolor', 5:'Halfmoon_Nemo',
              6:'Halfmoon_Red', 7:'Halfmoon_Red_Cooper', 8:'Plakat_Blue_Rim', 9:'Plakat_Platinum'}
def predict():
  random_data = np.random.randint(low = 0, high = len(X)-1, size=6)
  sample_images = X_test[random_data]
  sample_label = Y[random_data]
  predicted = model.predict(sample_images) # Memprediksi model
  predicted = np.argmax(predicted, axis=1) # Mengembalikan nilai terbesar dari array prediksi
  true_label = np.argmax(sample_label, axis=1) # Mengembalikan nilai terbesar dari array sample_label
  fig, axs = plt.subplots(3, 3)
  fig.set_size_inches(13,13)
  for row in range(3):
    for col in range(3):
      if row == 0:
        true = true_label[row+col]
        pred = predicted[row+col]
        axs[row, col].imshow(sample_images[row+col])
      else:
        true = true_label[row+col+1]
        pred = predicted[row+col+1]
        axs[row, col].imshow(sample_images[row+col+1])
      axs[row, col].set_title('True: %s\nPredicted: %s' % (dict_label[true], dict_label[pred]))
      axs[row, col].axis('off')

predict()

# %%
# Mengupload dan memprediksi gambar baru yang telah diupload
# Apabila run pertama error maka harus dirun 2x
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # memprediksi gambar
    path = fn
    img = image.load_img(path, target_size=(150,150))
    imgplot = plt.imshow(img)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
 
    images = np.vstack([x])
    pred = model.predict(images, batch_size=10)
    classes = np.argmax(pred,axis=1)
  
    print(classes)
    if classes == 0:
      print('Crowntail_Black_Orchid')
    elif classes == 1:
      print('Crowntail_Super_Red')
    elif classes == 2:
      print('Halfmoon_Big_Ear')
    elif classes == 3:
      print('Halfmoon_Blue')
    elif classes == 4:
      print('Halfmoon_Multicolor')
    elif classes == 5:
      print('Halfmoon_Nemo')
    elif classes == 6:
      print('Halfmoon_Red')
    elif classes == 7:
      print('Halfmoon_Red_Cooper')
    elif classes == 8:
      print('Plakat_Blue_Rim')    
    else :
      print('Plakat_Platinum')
# Out:
#      <input type="file" id="files-1791fe3c-23e0-4ba1-acbb-805128dcbad5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1791fe3c-23e0-4ba1-acbb-805128dcbad5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HalfmoonMulticolor (6).jpg to HalfmoonMulticolor (6).jpg
# [4]
# Halfmoon_Multicolor
